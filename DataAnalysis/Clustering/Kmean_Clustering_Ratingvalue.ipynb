# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# # K-mean Clustering for Data Analysis
#     -  We use k-means clustering to identify the most important features that contribute to app success, such as the size of the app or the minimum Android version required...

# %% [markdown]
# ## Read Data

# %%
# read data as dataframe from csv file
df = pd.read_csv('../../Dataset/Preprocessed_data.csv', error_bad_lines=False)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3960\1127482945.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('../../Dataset/Preprocessed_data.csv', error_bad_lines=False)
# b'Skipping line 78700: expected 20 fields, saw 21\nSkipping line 85033: expected 20 fields, saw 21\n'
# b'Skipping line 128092: expected 20 fields, saw 22\n'
# b'Skipping line 197000: expected 20 fields, saw 21\nSkipping line 218421: expected 20 fields, saw 21\n'
# b'Skipping line 330474: expected 20 fields, saw 21\nSkipping line 337681: expected 20 fields, saw 21\n'
# b'Skipping line 556266: expected 20 fields, saw 21\n'
# b'Skipping line 641092: expected 20 fields, saw 21\n'
# b'Skipping line 759119: expected 20 fields, saw 21\n'
# b'Skipping line 801997: expected 20 fields, saw 22\n'
# b'Skipping line 823248: expected 20 fields, saw 21\n'
# b'Skipping line 1044981: expected 20 fields, saw 21\n'
# ...

# %%
#print siza of the data
print(df.shape)
# Out:
# (1900333, 20)

# %%
df.head(10)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
# 5                                             IMOCCI
# 6                   unlimited 4G data prank free app
# 7                              The Everyday Calendar
# 8                                          WhatsOpen
# 9                                    Dodge The Cars!
#
#                                           App Id          Category Rating  \
# 0                            com.ishakwe.gakondo         Adventure    0.0
# 1                     com.webserveis.batteryinfo             Tools    4.4
# 2                           com.doantiepvien.crm      Productivity    0.0
# 3                        cst.stJoseph.ug17ucs548     Communication    5.0
# ...

# %%
# keep only 0.25 of the data
df = df.sample(frac=0.25, random_state=1)

# %% [markdown]
# ### Clean Data

# %%
df=convert_to_numeric(df)
df.head(10)
# Out:
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\Clustering\utils.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '').astype(float)
#                                                   App Name  \
# 1885170                 Archivo Audiovisual Poesía Peruana
# 1190381                              Gilly Bonny Online Tv
# 1612394  PlayMusic: A Stylish Music Player Ever in Andr...
# 1836893                                Dealer Trade Direct
# 1732655                       East Coast Jiu Jitsu Academy
# 368962                          Formadores - Fundacoofisam
# 287269                                          PediaDosis
# 1758056                         Deal: A Green New Election
# 973530      Ashoka Institute of Engineering and Technology
# ...

# %% [markdown]
# ## select required features
#     - we will cluster apps to groups based on their features and identify the most important features that contribute to app success.
#     -K-means clustering is designed to work with continuous features so we will select them
#     -By analyzing the clusters, you can identify which features are most strongly associated with successful apps, such as high ratings, large number of downloads,

# %%
#convert rating count column to float
df['Rating Count'] = df['Rating Count'].astype(float)
# add a new column called Rating_Value which equal rating * rating count
df['Rating_Value'] = df['Rating'] * df['Rating Count']

# %%
# select installs and size (MB) columns
data = df[[ 'Size', 'Installs', 'Rating_Value']]
data.head(10)
#print data type of each column
# Out:
#               Size  Installs  Rating_Value
# 1885170   0.000007       5.0           0.0
# 1190381  11.000000    1000.0          63.0
# 1612394  11.000000     100.0           0.0
# 1836893   0.000003     100.0           0.0
# 1732655  10.000000     500.0          30.0
# 368962    0.000004      10.0           0.0
# 287269    0.000004    1000.0          20.0
# 1758056  26.000000     100.0           0.0
# 973530   13.000000     100.0          55.2
# 1642186   0.000001     500.0          72.0

# %% [markdown]
# ## choose optimal value of k

# %% [markdown]
# ### 1- Elbow method

# %%
elbow_method(data)
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ### Result
#     Optimal value for k is 3

# %% [markdown]
# ### Centroid initilization with Kmean++

# %%
initial_centroids=kmeans_plus_plus(data, 3)
# Out:
# Initial centroids:  [array([5.2e-06, 1.0e+02, 0.0e+00]), array([  26., 5000.,   21.]), array([4.400e-06, 1.000e+04, 3.225e+02])]

# %% [markdown]
# ## Apply K-mean

# %%
X,kmeans=k_mean(data, 3, initial_centroids)
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1362: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ### Evaluate with Silhouette Score

# %% [markdown]
# ### Plot Clusters

# %%
plot_clusters(df, X,kmeans)

# %% [markdown]
# ## Insights
# - cluster1: least number of installs, max size,
# - cluster2: medium number of installs, medium size,
# - cluster3: max number of installs, min size\
#
#         - all clusters have the same range of rating
#         - all clusters have similar range of size < 200 MB
#           however cluster3 with min installs has the highest size
#           similarly cluster2 with max install has the lowest size
#
#         so we can conclude that:
#         1- size has no effect on rating the app.
#         2- number of installs slightly affected by size as apps
#            with less size tends to have higher number of installs
#            but it's not the major factor affects the installs.
