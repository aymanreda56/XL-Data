# %%
import findspark; findspark.init()
import pyspark
from pyspark.sql import SparkSession

from pyspark.sql.functions import *
import matplotlib.pyplot as plt
import seaborn as sns

import sys; sys.path.append("../../")
from DataPreprocessing.DataPreprocessing import read_data
import CorrelationAnalysis

# %% [markdown]
# # Spark session

# %%
sc = SparkContext(master='local')
spark = SparkSession.builder.appName("CorrelationAnalysis").getOrCreate()

# %% [markdown]
# # Correlation matrix

# %% [markdown]
# ### Numerical Features

# %%
df_num =read_data(spark, features='Numerical')
CorrelationAnalysis.numerical_corr(df_num)

# %% [markdown]
# ### Categorical Features

# %%
df_categ = read_data(spark, features='Categorical',\
               useless_cols=['App Name','App Id','Developer Id','Developer Email'])

CorrelationAnalysis.categorical_corr(df_categ)
