# %%
import sys; sys.path.append("../../")
import pandas as pd
import matplotlib.pyplot as plt
from DataPreprocessing.DataPreprocessing import *
from utils import *
plt.style.use('dark_background')

# %% [markdown]
# # Analyze Rating

# %% [markdown]
# ## Question 1
#     Does rating of the app affected by whether the app support ads or not?

# %% [markdown]
# ## Read Data

# %%
# read data as dataframe from csv file
df = pd.read_csv('../../Dataset/Preprocessed_data.csv', error_bad_lines=False)
print(df.shape)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6452\377713779.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('../../Dataset/Preprocessed_data.csv', error_bad_lines=False)
# b'Skipping line 78700: expected 20 fields, saw 21\nSkipping line 85033: expected 20 fields, saw 21\n'
# b'Skipping line 128092: expected 20 fields, saw 22\n'
# b'Skipping line 197000: expected 20 fields, saw 21\nSkipping line 218421: expected 20 fields, saw 21\n'
# b'Skipping line 330474: expected 20 fields, saw 21\nSkipping line 337681: expected 20 fields, saw 21\n'
# b'Skipping line 556266: expected 20 fields, saw 21\n'
# b'Skipping line 641092: expected 20 fields, saw 21\n'
# b'Skipping line 759119: expected 20 fields, saw 21\n'
# b'Skipping line 801997: expected 20 fields, saw 22\n'
# b'Skipping line 823248: expected 20 fields, saw 21\n'
# b'Skipping line 1044981: expected 20 fields, saw 21\n'
# b'Skipping line 1138871: expected 20 fields, saw 21\n'
# b'Skipping line 1206283: expected 20 fields, saw 21\n'
# b'Skipping line 1313239: expected 20 fields, saw 21\n'
# b'Skipping line 1392796: expected 20 fields, saw 21\n'
# b'Skipping line 1504892: expected 20 fields, saw 21\n'
# b'Skipping line 1592677: expected 20 fields, saw 21\n'
# b'Skipping line 1674183: expected 20 fields, saw 21\n'
# b'Skipping line 1823007: expected 20 fields, saw 21\n'
# C:\Users\dell\AppData\Local\Temp\ipykernel_6452\377713779.py:2: DtypeWarning: Columns (3,4,6,7,8,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../Dataset/Preprocessed_data.csv', error_bad_lines=False)
# (1900333, 20)

# %%
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category Rating Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure    0.0            0      10+
# 1  com.webserveis.batteryinfo          Tools    4.4           64   5,000+
# 2        com.doantiepvien.crm   Productivity    0.0            0      50+
# 3     cst.stJoseph.ug17ucs548  Communication    5.0            5      10+
# 4        com.horodyski.grower          Tools    0.0            0     100+
#
#   Minimum Installs Maximum Installs  Free  Price       Size Minimum Android  \
# 0               10               15  True    0.0   10000000      7.1 and up
# 1             5000             7662  True    0.0  2.9000000      5.0 and up
# 2               50               58  True    0.0  3.7000000    4.0.3 and up
# 3               10               19  True    0.0  1.8000000    4.0.3 and up
# 4              100              478  True    0.0  6.2000000      4.1 and up
#
#                         Developer Id              Developer Email  \
# 0  Jean Confident Irénée NIYIZIBYOSE       jean21101999@gmail.com
# 1                         Webserveis         webserveis@gmail.com
# 2                         Cabin Crew          vnacrewit@gmail.com
# 3                Climate Smart Tech2  climatesmarttech2@gmail.com
# 4              Rafal Milek-Horodyski    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating Ad Supported In App Purchases  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone        False            False
# 1  May 21, 2020  May 06, 2021       Everyone         True            False
# 2   Aug 9, 2019  Aug 19, 2019       Everyone        False            False
# 3  Sep 10, 2018  Oct 13, 2018       Everyone         True            False
# 4  Feb 21, 2020  Nov 12, 2018       Everyone        False            False
#
#   Editors Choice
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %% [markdown]
# ## Clean

# %%
df = convert_to_numeric(df)
df=convert_binary(df)
df.head(10)
# Out:
# ../..\DataPreprocessing\DataPreprocessing.py:223: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '').astype(float)
# ../..\DataPreprocessing\DataPreprocessing.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.replace('True', '1')
# ../..\DataPreprocessing\DataPreprocessing.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.replace('False', '0')
#                                            App Name  \
# 1669829   Technology Blue Theme - Art Fine Launcher
# 1625956                                 Envy Motors
# 7106                             Oriva Life Science
# 1876117                 walkthrough for Apex Mobile
# 1107419                             My Club Manager
# 677249                              MAK - G ACADEMY
# 592026                                         耀豐證券
# 1863989          RD Sharma Class 9th Math Solutions
# 933851   Wooly - ⏱️ Row Counter & 🧶 Knitting Helper
# 965107                Eng-Kh Civil Engineering Dict
#
#                                                App Id         Category  \
# 1669829  store.artfine.launcher.technology_blue_theme  Personalization
# 1625956                com.envymotors.cem.members.app        Lifestyle
# 7106                                        com.oriva         Business
# 1876117                     com.HzGames.LegendsMobile     Role Playing
# 1107419                         com.bonappetit.myclub           Sports
# 677249                                  co.stan.lulbi        Education
# 592026                        hk.com.ayers.hjtf.trade          Finance
# 1863989     com.appedusoft.class9mathssolutionssharma        Education
# 933851                            com.devbyemil.wooly            Tools
# 965107                      com.vithda.blogspot.cedek        Education
#
#          Rating Rating Count  Installs Minimum Installs Maximum Installs Free  \
# 1669829     5.0            8    1000.0             1000             1412    1
# 1625956     0.0            0     100.0              100              255    1
# 7106        0.0            0      50.0               50               97    1
# 1876117     0.0            0     100.0              100              116    1
# 1107419     0.0            0      10.0               10               43    1
# 677249      0.0            0      10.0               10               44    1
# 592026      0.0            0     100.0              100              111    1
# 1863989     4.2           45    1000.0             1000             4400    1
# 933851      4.3           11     100.0              100              227    1
# 965107      4.4           17    1000.0             1000             2292    1
#
#          Price       Size Minimum Android                   Developer Id  \
# 1669829    0.0   0.000005             5.0                  ARTFINE.STORE
# 1625956    0.0  14.000000             5.0            Envy Motors Pte Ltd
# 7106       0.0   0.000004             4.0  Infotus E-Technology Pvt. Ltd
# 1876117    0.0  88.000000             4.4                    Hz Games 21
# 1107419    0.0   0.000005             5.0                    Ben O'Neill
# 677249     0.0  32.000000             4.2           Education Star Media
# 592026     0.0  17.000000             7.0    YieldFul Securities Limited
# 1863989    0.0  31.000000             4.1                   App Edu Soft
# 933851     0.0  19.000000             5.0                      devbyemil
# 965107     0.0   0.000002             2.2                      In Davith
#
#                        Developer Email      Released  Last Updated  \
# 1669829          artfine.app@gmail.com  Nov 21, 2018  Nov 21, 2018
# 1625956         info@envymotors.com.sg  Nov 28, 2019  Apr 06, 2020
# 7106     infotustechnologies@gmail.com  Jan 16, 2019  Mar 17, 2019
# 1876117            hzgames21@gmail.com   May 9, 2021  May 10, 2021
# 1107419        bonappetitdev@gmail.com  Sep 27, 2019  Sep 27, 2019
# 677249            support@classplus.co  Mar 17, 2021  May 17, 2021
# 592026                 it@shinenex.com  Jun 21, 2018  Feb 10, 2021
# 1863989         jyotitkamdar@gmail.com  Aug 21, 2018  Jul 16, 2019
# 933851           devbyemil@t-online.de  Mar 22, 2021  Jun 06, 2021
# 965107        android.davith@gmail.com   Nov 3, 2014  Nov 04, 2014
#
#         Content Rating Ad Supported In App Purchases Editors Choice
# 1669829       Everyone            1                0              0
# 1625956       Everyone            0                0              0
# 7106          Everyone            1                0              0
# 1876117       Everyone            1                0              0
# 1107419       Everyone            0                0              0
# 677249        Everyone            0                0              0
# 592026        Everyone            0                0              0
# 1863989       Everyone            1                0              0
# 933851        Everyone            0                1              0
# 965107        Everyone            1                0              0

# %% [markdown]
# ## Select Interesting  Variables

# %%
features_df = df[[ 'Ad Supported', 'Rating', 'Content Rating','Minimum Android']]
print(features_df.shape)
# Out:
# (285047, 4)

# %% [markdown]
# ### Add rating value column to represent real representation for the rating

# %%
#convert rating count column to float
df['Rating Count'] = df['Rating Count'].astype(float)
# add a new column called Rating_Value which equal rating * rating count
df['Rating_Value'] = df['Rating'] * df['Rating Count']

# %%
features_df.head(10)
# Out:
#         Ad Supported  Rating Content Rating Minimum Android
# 1669829            1     5.0       Everyone             5.0
# 1625956            0     0.0       Everyone             5.0
# 7106               1     0.0       Everyone             4.0
# 1876117            1     0.0       Everyone             4.4
# 1107419            0     0.0       Everyone             5.0
# 677249             0     0.0       Everyone             4.2
# 592026             0     0.0       Everyone             7.0
# 1863989            1     4.2       Everyone             4.1
# 933851             0     4.3       Everyone             5.0
# 965107             1     4.4       Everyone             2.2

# %% [markdown]
# ## Rating values distribution
#     from the histogram we found that 0 rating is max value, that tends
#     to have the meaning of no ratings not 0 rating so it' better to drop
#     it as it affects the mean of rating a lot

# %%
plt.hist(df['Rating'])
# Out:
# (array([155761.,      0.,    407.,   1298.,   2565.,   5128.,  10832.,
#          20781.,  37217.,  51058.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
df=df.assign(IsRated= df['Rating'].apply(lambda x: 1 if x *1 > 0 else 0))

# %%
print(df.columns)
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Size',
#        'Minimum Android', 'Developer Id', 'Developer Email', 'Released',
#        'Last Updated', 'Content Rating', 'Ad Supported', 'In App Purchases',
#        'Editors Choice', 'Rating_Value', 'IsRated'],
#       dtype='object')

# %%
apps_rated = df.groupby('Ad Supported')['IsRated'].sum().head(10)
# plot pie chart for the number of apps rated and not rated for ad supported apps and not ad supported apps
plt.pie(apps_rated, labels=['no Ads', 'support Ads'], autopct='%1.1f%%',startangle=90)
# set the title for the figure
plt.title("which apps got rated more?", fontsize=20)
# show the figure
plt.show()

# %% [markdown]
# ### Mean of app ratings for ad supported/ not supported

# %% [markdown]
# #### 1- assuming zeros are ratings

# %%
app_rating = df.groupby('Ad Supported')['Rating_Value'].mean().sort_values(ascending=False).head(10)
app_rating.nlargest(15).plot(kind='bar', figsize=(7, 4))
# Out:
# <Axes: xlabel='Ad Supported'>

# %% [markdown]
# #### 2- assuming zeros are no rating

# %%
df = df[df['Rating'] != 0.0]
app_rating = df.groupby('Ad Supported')['Rating_Value'].mean().sort_values(ascending=False).head(10)
app_rating.nlargest(15).plot(kind='bar', figsize=(7, 4))
# Out:
# <Axes: xlabel='Ad Supported'>

# %% [markdown]
# ## Question 2
#     Is there a relation between rating and last update?

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Last Updated'] = df['Last Updated'].dt.year
print("Unique values in Last Updated: ", df['Last Updated'].unique())
# Out:
# Unique values in Last Updated:  [2018 2019 2021 2014 2013 2020 2015 2017 2011 2016 2012 2010 2009]

# %%
df['Released'] = pd.to_datetime(df['Released'])
df['Released'] = df['Released'].dt.year
print("Unique values in Released: ", df['Released'].unique())
# Out:
# Unique values in Released:  [2018 2021 2014 2013 2020 2019 2017 2015 2016 2012 2011 2010]

# %%
content_rating = df.groupby('Last Updated')['Rating_Value'].mean().sort_values(ascending=False).head(10)
content_rating.nlargest(15).plot(kind='bar', figsize=(7, 4))
# Out:
# <Axes: xlabel='Last Updated'>

# %%
sub_blot(df, "Released", "Last Updated", "Rating_Value", "Mean Ratings by Last Updated for each category")

# %% [markdown]
# ## Results
# - the year with highest rating is not the latest one so, last up date has no effect on rating.

# %% [markdown]
# ## Question 3
#     Is there a relation between rating and content rating?

# %%
#get unique values of content rating
content_rating = df.groupby('Content Rating')['Rating'].mean().sort_values(ascending=False).head(10)
content_rating.nlargest(15).plot(kind='bar', figsize=(7, 4), title='Mean Rating for each content rating')
# Out:
# <Axes: title={'center': 'Mean Rating for each content rating'}, xlabel='Content Rating'>

# %%
sub_blot(df, "Category", "Content Rating", "Rating", "Mean Ratings by Content Rating for each category")

# %% [markdown]
# # Question 4
#     can we estimate the best developers from ratings of the apps?

# %%
# get developer of the top 10 apps with highest rating value
developers_ratings = df.groupby('Developer Id')['Rating_Value'].mean().sort_values(ascending=False)
# plot bar chart for the top 10 developers
developers_ratings.nlargest(20).plot(kind='bar', figsize=(7, 4), title='Top 20 Developers with highest rating value',style='dark_background')
# Out:
# <Axes: title={'center': 'Top 20 Developers with highest rating value'}, xlabel='Developer Id'>
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54021 (\N{HANGUL SYLLABLE TING}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51076 (\N{HANGUL SYLLABLE IM}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51592 (\N{HANGUL SYLLABLE JEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54021 (\N{HANGUL SYLLABLE TING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44172 (\N{HANGUL SYLLABLE GE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51076 (\N{HANGUL SYLLABLE IM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51592 (\N{HANGUL SYLLABLE JEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Top 10 developers in each app category

# %%
sub_blot(df, "Category", "Developer Id", "Rating_Value", "Mean Ratings by Content Rating for each category")
# Out:
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 28145 (\N{CJK UNIFIED IDEOGRAPH-6DF1}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 22323 (\N{CJK UNIFIED IDEOGRAPH-5733}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 24066 (\N{CJK UNIFIED IDEOGRAPH-5E02}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 28023 (\N{CJK UNIFIED IDEOGRAPH-6D77}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 21407 (\N{CJK UNIFIED IDEOGRAPH-539F}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 32593 (\N{CJK UNIFIED IDEOGRAPH-7F51}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 32476 (\N{CJK UNIFIED IDEOGRAPH-7EDC}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 25216 (\N{CJK UNIFIED IDEOGRAPH-6280}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 26415 (\N{CJK UNIFIED IDEOGRAPH-672F}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 38480 (\N{CJK UNIFIED IDEOGRAPH-9650}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:11: UserWarning: Glyph 21496 (\N{CJK UNIFIED IDEOGRAPH-53F8}) missing from current font.
#   plt.tight_layout()
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28145 (\N{CJK UNIFIED IDEOGRAPH-6DF1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22323 (\N{CJK UNIFIED IDEOGRAPH-5733}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24066 (\N{CJK UNIFIED IDEOGRAPH-5E02}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28023 (\N{CJK UNIFIED IDEOGRAPH-6D77}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21407 (\N{CJK UNIFIED IDEOGRAPH-539F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32593 (\N{CJK UNIFIED IDEOGRAPH-7F51}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32476 (\N{CJK UNIFIED IDEOGRAPH-7EDC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25216 (\N{CJK UNIFIED IDEOGRAPH-6280}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26415 (\N{CJK UNIFIED IDEOGRAPH-672F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 38480 (\N{CJK UNIFIED IDEOGRAPH-9650}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21496 (\N{CJK UNIFIED IDEOGRAPH-53F8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Insights
# - unlike our expectations ratings are not affected by ads.
# - there's no correlation between rating of app and its last update.
# - as expected most of tne content ratings unrated.
# - for specific app category there's a content rating type that has highest
#   rating than other ,so company can know which category of people prefer which
#   app category.
# - Rating value can be used to get the best developers/SW companies in each app category.
# - Conclusion:
#   - Data doesn't match all the expectation because data columns is not enough, we need
#     more columns about app content like (How attractive the UI, user experience , number of ads ..) to make more insights about what factor affect ratings.
