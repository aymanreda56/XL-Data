# %%
import sys; sys.path.append("../../")
import pandas as pd
import matplotlib.pyplot as plt
from DataPreprocessing.DataPreprocessing import *
from utils import *

# %% [markdown]
# # Analyze Rating

# %% [markdown]
# ## Question 1
#     Does rating of the app affected by whether the app support ads or not?

# %% [markdown]
# ## Read Data

# %%
# read data as dataframe from csv file
df = pd.read_csv('../../Dataset/Preprocessed_data.csv', error_bad_lines=False)
print(df.shape)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8668\377713779.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('../../Dataset/Preprocessed_data.csv', error_bad_lines=False)
# b'Skipping line 78700: expected 20 fields, saw 21\nSkipping line 85033: expected 20 fields, saw 21\n'
# b'Skipping line 128092: expected 20 fields, saw 22\n'
# b'Skipping line 197000: expected 20 fields, saw 21\nSkipping line 218421: expected 20 fields, saw 21\n'
# b'Skipping line 330474: expected 20 fields, saw 21\nSkipping line 337681: expected 20 fields, saw 21\n'
# b'Skipping line 556266: expected 20 fields, saw 21\n'
# b'Skipping line 641092: expected 20 fields, saw 21\n'
# b'Skipping line 759119: expected 20 fields, saw 21\n'
# b'Skipping line 801997: expected 20 fields, saw 22\n'
# b'Skipping line 823248: expected 20 fields, saw 21\n'
# b'Skipping line 1044981: expected 20 fields, saw 21\n'
# b'Skipping line 1138871: expected 20 fields, saw 21\n'
# b'Skipping line 1206283: expected 20 fields, saw 21\n'
# b'Skipping line 1313239: expected 20 fields, saw 21\n'
# b'Skipping line 1392796: expected 20 fields, saw 21\n'
# b'Skipping line 1504892: expected 20 fields, saw 21\n'
# b'Skipping line 1592677: expected 20 fields, saw 21\n'
# b'Skipping line 1674183: expected 20 fields, saw 21\n'
# b'Skipping line 1823007: expected 20 fields, saw 21\n'
# C:\Users\dell\AppData\Local\Temp\ipykernel_8668\377713779.py:2: DtypeWarning: Columns (3,4,6,7,8,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../Dataset/Preprocessed_data.csv', error_bad_lines=False)
# (1900333, 20)

# %%
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category Rating Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure    0.0            0      10+
# 1  com.webserveis.batteryinfo          Tools    4.4           64   5,000+
# 2        com.doantiepvien.crm   Productivity    0.0            0      50+
# 3     cst.stJoseph.ug17ucs548  Communication    5.0            5      10+
# 4        com.horodyski.grower          Tools    0.0            0     100+
#
#   Minimum Installs Maximum Installs  Free  Price       Size Minimum Android  \
# 0               10               15  True    0.0   10000000      7.1 and up
# 1             5000             7662  True    0.0  2.9000000      5.0 and up
# 2               50               58  True    0.0  3.7000000    4.0.3 and up
# 3               10               19  True    0.0  1.8000000    4.0.3 and up
# 4              100              478  True    0.0  6.2000000      4.1 and up
#
#                         Developer Id              Developer Email  \
# 0  Jean Confident Irénée NIYIZIBYOSE       jean21101999@gmail.com
# 1                         Webserveis         webserveis@gmail.com
# 2                         Cabin Crew          vnacrewit@gmail.com
# 3                Climate Smart Tech2  climatesmarttech2@gmail.com
# 4              Rafal Milek-Horodyski    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating Ad Supported In App Purchases  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone        False            False
# 1  May 21, 2020  May 06, 2021       Everyone         True            False
# 2   Aug 9, 2019  Aug 19, 2019       Everyone        False            False
# 3  Sep 10, 2018  Oct 13, 2018       Everyone         True            False
# 4  Feb 21, 2020  Nov 12, 2018       Everyone        False            False
#
#   Editors Choice
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %% [markdown]
# ## Clean

# %%
df = convert_to_numeric(df)
df=convert_binary(df)
df.head(10)
# Out:
# ../..\DataPreprocessing\DataPreprocessing.py:223: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '').astype(float)
# ../..\DataPreprocessing\DataPreprocessing.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.replace('True', '1')
# ../..\DataPreprocessing\DataPreprocessing.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype(str).str.replace('False', '0')
#                                                   App Name  \
# 1656229                                     Robot Arm Test
# 941659                                    Clean Calculator
# 636314                                            Onlykart
# 1166269  Old Age Maker | Old Face Maker | Make Wrinkle ...
# 653813                         Animals Sounds for Toddlers
# 1090593                                 Keyboard Plus Fast
# 365818                                    Happy Nurses Day
# 1766611                                           Köstebek
# 858458                                     DiziHaberci.Com
# 149559             আবিষ্কার ও আবিষ্কারক~বাংলা সাধারণ জ্ঞান
#
#                                                     App Id          Category  \
# 1656229                      com.sulaimanvali.robotarmtest     Entertainment
# 941659                                 io.clean.calculator             Tools
# 636314                             com.apextiming.onlykart     Entertainment
# 1166269  com.bestappsstore.oldfaces.makeoldage.makeoldf...       Photography
# 653813      com.KidsGamesProjects.AnimalsSoundsForToddlers       Educational
# 1090593                             com.keyboard.plus.fast   Personalization
# 365818                        com.rnamobile.happynursesday         Lifestyle
# 1766611                                com.BoRoVa.Kostebek             Board
# 858458                                  com.dizihabercicom  News & Magazines
# 149559                           com.dreamfighter.abishkar         Education
#
#          Rating Rating Count  Installs Minimum Installs Maximum Installs Free  \
# 1656229     4.2           18    1000.0             1000             3730    1
# 941659      0.0            0      10.0               10               31    1
# 636314      4.7            6    1000.0             1000             1276    1
# 1166269     4.2          123   10000.0            10000            13731    1
# 653813      4.1           22    5000.0             5000             6488    1
# 1090593     4.0           90   10000.0            10000            10075    1
# 365818      0.0            0     100.0              100              499    1
# 1766611     0.0            0       1.0                1                3    1
# 858458      0.0            0      10.0               10               24    1
# 149559      0.0            0    1000.0             1000             1147    1
#
#          Price       Size Minimum Android  \
# 1656229    0.0   0.000001           4.0.3
# 941659     0.0   0.000004             4.4
# 636314     0.0   0.000003             4.4
# 1166269    0.0  11.000000             4.3
# 653813     0.0  68.000000           4.0.3
# 1090593    0.0   0.000003             4.2
# 365818     0.0  14.000000           4.0.3
# 1766611    0.0  50.000000             4.1
# 858458     0.0   0.000006             4.1
# 149559     0.0   0.000003             4.2
#
#                                             Developer Id  \
# 1656229                                     sulaimanvali
# 941659                                             ZhuYu
# 636314                                       Apex Timing
# 1166269                                  Sparkling India
# 653813                               Kids Games Projects
# 1090593                          Free Keyboard Themes HD
# 365818                                         rnamobile
# 1766611                       Digital World Technologies
# 858458   EniyiWeb Tasarım İnternet ve Bilişim Hizmetleri
# 149559                                     Dream Fighter
#
#                       Developer Email      Released  Last Updated  \
# 1656229       sulaiman.vali@gmail.com   Jan 2, 2016  Jan 02, 2016
# 941659          jimmy.zhuyu@gmail.com  Jul 11, 2019  Jul 11, 2019
# 636314      webmaster@apex-timing.com   Sep 8, 2017  Sep 08, 2017
# 1166269  worldofsuccess2020@gmail.com  Jan 14, 2021  May 26, 2021
# 653813     kidsgameprojects@gmail.com  Feb 24, 2017  Mar 03, 2017
# 1090593       thememasters1@gmail.com  Dec 24, 2014  Jun 07, 2018
# 365818            rnamobile@yahoo.com  Apr 23, 2020  Apr 23, 2020
# 1766611         cihanborova@gmail.com  Aug 11, 2017  Aug 12, 2017
# 858458              info@eniyiweb.net  Jul 20, 2019  Aug 16, 2019
# 149559       dreamfighterbd@gmail.com  Oct 13, 2018  Jan 20, 2019
#
#         Content Rating Ad Supported In App Purchases Editors Choice
# 1656229       Everyone            0                0              0
# 941659        Everyone            0                0              0
# 636314        Everyone            0                0              0
# 1166269       Everyone            1                0              0
# 653813        Everyone            0                0              0
# 1090593       Everyone            1                0              0
# 365818            Teen            1                0              0
# 1766611       Everyone            0                0              0
# 858458        Everyone            1                0              0
# 149559        Everyone            1                0              0

# %% [markdown]
# ## Select Interesting  Variables

# %%
features_df = df[[ 'Ad Supported', 'Rating', 'Content Rating','Minimum Android']]
print(features_df.shape)
# Out:
# (285047, 4)

# %% [markdown]
# ### Add rating value column to represent real representation for the rating

# %%
#convert rating count column to float
df['Rating Count'] = df['Rating Count'].astype(float)
# add a new column called Rating_Value which equal rating * rating count
df['Rating_Value'] = df['Rating'] * df['Rating Count']

# %%
features_df.head(10)
# Out:
#         Ad Supported  Rating Content Rating Minimum Android
# 1656229            0     4.2       Everyone           4.0.3
# 941659             0     0.0       Everyone             4.4
# 636314             0     4.7       Everyone             4.4
# 1166269            1     4.2       Everyone             4.3
# 653813             0     4.1       Everyone           4.0.3
# 1090593            1     4.0       Everyone             4.2
# 365818             1     0.0           Teen           4.0.3
# 1766611            0     0.0       Everyone             4.1
# 858458             1     0.0       Everyone             4.1
# 149559             1     0.0       Everyone             4.2

# %% [markdown]
# ## Rating values distribution
#     from the histogram we found that 0 rating is max value, that tends
#     to have the meaning of no ratings not 0 rating so it' better to drop
#     it as it affects the mean of rating a lot

# %%
plt.hist(df['Rating'])
# Out:
# (array([155936.,      0.,    380.,   1219.,   2636.,   5249.,  10840.,
#          20592.,  37117.,  51078.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
df=df.assign(IsRated= df['Rating'].apply(lambda x: 1 if x *1 > 0 else 0))

# %%
print(df.columns)
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Size',
#        'Minimum Android', 'Developer Id', 'Developer Email', 'Released',
#        'Last Updated', 'Content Rating', 'Ad Supported', 'In App Purchases',
#        'Editors Choice', 'Rating_Value', 'IsRated'],
#       dtype='object')

# %%
apps_rated = df.groupby('Ad Supported')['IsRated'].sum().head(10)
# plot pie chart for the number of apps rated and not rated for ad supported apps and not ad supported apps
plt.pie(apps_rated, labels=['no Ads', 'support Ads'], autopct='%1.1f%%',startangle=90)
# set the title for the figure
plt.title("which apps got rated more?", fontsize=20)
# show the figure
plt.show()

# %% [markdown]
# ### Mean of app ratings for ad supported/ not supported

# %% [markdown]
# #### 1- assuming zeros are ratings

# %%
app_rating = df.groupby('Ad Supported')['Rating_Value'].mean().sort_values(ascending=False).head(10)
app_rating.nlargest(15).plot(kind='bar', figsize=(7, 4))
# Out:
# <Axes: xlabel='Ad Supported'>

# %% [markdown]
# #### 2- assuming zeros are no rating

# %%
df = df[df['Rating'] != 0.0]
app_rating = df.groupby('Ad Supported')['Rating_Value'].mean().sort_values(ascending=False).head(10)
app_rating.nlargest(15).plot(kind='bar', figsize=(7, 4))
# Out:
# <Axes: xlabel='Ad Supported'>

# %% [markdown]
# ## Question 2
#     Is there a relation between rating and last update?

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Last Updated'] = df['Last Updated'].dt.year
print("Unique values in Last Updated: ", df['Last Updated'].unique())
# Out:
# Unique values in Last Updated:  [2016 2019 2017 2021 2018 2020 2015 2014 2011 2013 2012 2010 2009]

# %%
df['Released'] = pd.to_datetime(df['Released'])
df['Released'] = df['Released'].dt.year
print("Unique values in Released: ", df['Released'].unique())
# Out:
# Unique values in Released:  [2016 2019 2017 2021 2014 2020 2018 2013 2015 2012 2011 2010]

# %%
content_rating = df.groupby('Last Updated')['Rating_Value'].mean().sort_values(ascending=False).head(10)
content_rating.nlargest(15).plot(kind='bar', figsize=(7, 4))
# Out:
# <Axes: xlabel='Last Updated'>

# %%
sub_blot(df, "Released", "Last Updated", "Rating_Value", "Mean Ratings by Last Updated for each category")

# %%
# ANOVA_test(df, 'Last Updated', 'Rating')

# %% [markdown]
# ## Question 3
#     Is there a relation between rating and content rating?

# %%
#get unique values of content rating
content_rating = df.groupby('Content Rating')['Rating'].mean().sort_values(ascending=False).head(10)
content_rating.nlargest(15).plot(kind='bar', figsize=(7, 4), title='Mean Rating for each content rating')
# Out:
# <Axes: title={'center': 'Mean Rating for each content rating'}, xlabel='Content Rating'>

# %%
sub_blot(df, "Category", "Content Rating", "Rating", "Mean Ratings by Content Rating for each category")

# %% [markdown]
# # Question 4
#     can we estimate the best developers from ratings of the apps?

# %%
# get developer of the top 10 apps with highest rating value
developers_ratings = df.groupby('Developer Id')['Rating_Value'].mean().sort_values(ascending=False)
# plot bar chart for the top 10 developers
developers_ratings.nlargest(20).plot(kind='bar', figsize=(7, 4), title='Top 20 Developers with highest rating value')
# Out:
# <Axes: title={'center': 'Top 20 Developers with highest rating value'}, xlabel='Developer Id'>

# %% [markdown]
# ### Top 10 developers in each app category

# %%
sub_blot(df, "Category", "Developer Id", "Rating_Value", "Mean Ratings by Content Rating for each category")
# Out:
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 54021 (\N{HANGUL SYLLABLE TING}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 28145 (\N{CJK UNIFIED IDEOGRAPH-6DF1}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 22323 (\N{CJK UNIFIED IDEOGRAPH-5733}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 24066 (\N{CJK UNIFIED IDEOGRAPH-5E02}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 28023 (\N{CJK UNIFIED IDEOGRAPH-6D77}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 21407 (\N{CJK UNIFIED IDEOGRAPH-539F}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 32593 (\N{CJK UNIFIED IDEOGRAPH-7F51}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 32476 (\N{CJK UNIFIED IDEOGRAPH-7EDC}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 25216 (\N{CJK UNIFIED IDEOGRAPH-6280}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 26415 (\N{CJK UNIFIED IDEOGRAPH-672F}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 38480 (\N{CJK UNIFIED IDEOGRAPH-9650}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 21496 (\N{CJK UNIFIED IDEOGRAPH-53F8}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 30526 (\N{CJK UNIFIED IDEOGRAPH-773E}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 21295 (\N{CJK UNIFIED IDEOGRAPH-532F}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 26234 (\N{CJK UNIFIED IDEOGRAPH-667A}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 33021 (\N{CJK UNIFIED IDEOGRAPH-80FD}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 20581 (\N{CJK UNIFIED IDEOGRAPH-5065}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 47553 (\N{HANGUL SYLLABLE RING}) missing from current font.
#   plt.tight_layout()
# e:\fourth year\second term\big data\project\XL-Data\DataAnalysis\DiagnosticAnalysis\utils.py:10: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from current font.
#   plt.tight_layout()
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54924 (\N{HANGUL SYLLABLE HOE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47112 (\N{HANGUL SYLLABLE RE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54021 (\N{HANGUL SYLLABLE TING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28145 (\N{CJK UNIFIED IDEOGRAPH-6DF1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22323 (\N{CJK UNIFIED IDEOGRAPH-5733}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24066 (\N{CJK UNIFIED IDEOGRAPH-5E02}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21069 (\N{CJK UNIFIED IDEOGRAPH-524D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28023 (\N{CJK UNIFIED IDEOGRAPH-6D77}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20048 (\N{CJK UNIFIED IDEOGRAPH-4E50}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 28216 (\N{CJK UNIFIED IDEOGRAPH-6E38}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21407 (\N{CJK UNIFIED IDEOGRAPH-539F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32593 (\N{CJK UNIFIED IDEOGRAPH-7F51}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32476 (\N{CJK UNIFIED IDEOGRAPH-7EDC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25216 (\N{CJK UNIFIED IDEOGRAPH-6280}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26415 (\N{CJK UNIFIED IDEOGRAPH-672F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 38480 (\N{CJK UNIFIED IDEOGRAPH-9650}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21496 (\N{CJK UNIFIED IDEOGRAPH-53F8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30526 (\N{CJK UNIFIED IDEOGRAPH-773E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21295 (\N{CJK UNIFIED IDEOGRAPH-532F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26234 (\N{CJK UNIFIED IDEOGRAPH-667A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 33021 (\N{CJK UNIFIED IDEOGRAPH-80FD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20581 (\N{CJK UNIFIED IDEOGRAPH-5065}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47553 (\N{HANGUL SYLLABLE RING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dell\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Insights
# - unlike our expectations ratings are not affected by ads.
# - there's no correlation between rating of app and its last update.
# - as expected most of tne content ratings unrated.
# - for specific app category there's a content rating type that has highest
#   rating than other ,so company can know which category of people prefer which
#   app category.
# - Rating value can be used to get the best developers/SW companies in each app category.
# - Conclusion:
#   - Data doesn't match all the expectation because data columns is not enough, we need
#     more columns about app content like (How attractive the UI, user experience , number of ads ..) to make more insights about what factor affect ratings.
